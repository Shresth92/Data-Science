# %% [markdown]
# # Goeduhub First Assignment

# %% [markdown]
# 1. We are having 3 list like this
#
# Colors = [“Yellow”,”Green”,”White”,”Black”]
#
# Fruits=[“Apple”,”Papaya”,”Mango”,”Orange”]
#
# Animals=[“Tiger”,”Lion”,”Deer”,”Zebra”]

# %% [markdown]
# i. Write a program that asks user to enter a Color/Fruit/Animal name and it should tell which category belongs to , like its is a fruit or color or Animal

# %%
Colors = ["Yellow","Green","White","Black"]
Fruits=["Apple","Papaya","Mango","Orange"]
Animals=["Tiger","Lion","Deer","Zebra"]

choice = input("Enter any Colour/Fruit/Animal")

if choice in Colours:
    print(f"Hey buddy {choice} is a colour")
elif choice in Fruits:
    print(f"Hey buddy {choice} is a fruit")
elif choice in Animals:
    print(f"Hey buddy {choice} is an animal")
else:
    print(f"Sorry! We don't know {} belongs to which category")

# %% [markdown]
#  ii. Write a program that asks user to enter two cities and it tells you if they both are in same country or not. For example if I enter yellow and Black, it will print "Both are colors" but if I enter yellow and Tiger it should print "They don't belong to same category"

# %%
Colors = ["Yellow","Green","White","Black"]
Fruits=["Apple","Papaya","Mango","Orange"]
Animals=["Tiger","Lion","Deer","Zebra"]

choice_1 = input("Enter your 1st choice any Colour/Fruit/Animal")
choice_2 = input("Enter your 1st choice any Colour/Fruit/Animal")

if (choice_1 in Colors) and (choice_2 in Colors):
    print(f"{choice_1} and {choice_2} are both colours")
elif (choice_1 in Fruits) and (choice_2 in Fruits):
    print(f"{choice_1} and {choice_2} are both fruits")
elif (choice_1 in Animals) and (choice_2 in Animals):
    print(f"{choice_1} and {choice_2} are both animals")
else:
    print(f"{choice_1} and {choice_2} are both belong to defferent category")

# %% [markdown]
# 2.  Write a python program that can tell you if your grade score good or not . Normal Score range is 40 to 60.
#
#   i. Ask user to enter his score.
#
#   ii. If it is below 40 to 60 range then print that score is low
#
#   iii. If it is above 60 then print that it is good otherwise print that it is normal

# %%
score = int(input("Enter your score"))

if score<40:
    print("Your score is low")
elif score>60:
    print("Your score is good")
else:
    print("Yo have scored normal")

# %% [markdown]
# 3.  After appearing in exam 10 times you got this result,
#
# result = ["Pass","Fail","Fail","Pass","Fail","Pass","Pass","Fail","Fail","Fail"]

# %%
result = ["Pass","Fail","Fail","Pass","Fail","Pass","Pass","Fail","Fail","Fail"]

for i in result:
    if i == "Pass":
        print(i)

# %% [markdown]
# 4. Using for loop figure out how many times you got Pass4.  Write a program that prints following shape
#
#         *
#         **
#         ***
#         ****
#         *****
#         ****
#         ***
#         **
#         *

# %%
n = 5

for i in range(5):
    print("*" * i)
for i in range(5):
    print("*" * n-i)

# %% [markdown]
# 5.   Lets say you are running a 50 km race. Write a program that,
#
# Upon completing each 10 km asks you "are you tired?"
# If you reply "yes" then it should break and print "you didn't finish the race"
#  If you reply "no" then it should continue and ask "are you tired" on every km
# If you finish all 50 km then it should print congratulations message

# %%
for i in range(50):
    if i==10 or i==20 or i==30 or i==40:
        choice = input("are you tired?")
        if choice == "yes":
            print("you didn't finish the race")
            break
    elif i==50:
        print("Congratulation You have finished race")
    print(f"You have covered {i} km")

# %% [markdown]
# 6.  Write a Python program to find those numbers which are divisible by 7 and multiple of 5, between 1500 and 2700 (both included).

# %%
for i in range(1500,2701):
    if i%5==0 and i%7==0:
        print(f"{i} is divisible by 7 and multiple of 5")
    else:
        print(f"{i} is not divisible by 7 and not a multiple of 5")

# %% [markdown]
# 7.   Print square of all numbers between 10 to 20 except even numbers

# %%
for i in range(10,20):
    if i%2 == 0:
        continue
    else:
        print(f"Square of {i} if {i**2}")

# %% [markdown]
# 8.  Your Marks for five Test(test1 to test5) looks like this,
#
# marks_list = [65, 75, 2100, 95, 83]
#
# Write a program that asks you to enter marks and program should tell you in which test that marks occurred. If marks is not found then it should print that as well.

# %%
marks_list = [65, 75, 2100, 95, 83]

marks = int(input("Enter your marks"))

if marks in marks_list:
    print(f"You have got {marks} marks in test series number {marks_list.index(marks) + 1}.")
else:
    print(f"You haven't got {marks} marks in any test series")
